# %% [markdown]
# ###Домашнее задание №1 (Задача 1 и Задача 2)

# %%
# Задание 1: Кортеж
# Сложность: Лёгкая

my_tuple = (15,35,47,84)
print(my_tuple[-2])
# Out:
# 47

# %%
# Задание 2: Подсчёт символов без пробелов
# Сложность: Средняя

text = input("Введите строку: ")
text_without_spaces = text.replace(" ", " ")
length = len(text_without_spaces)
print("Количество символов без пробелов:", length)
# Out:
# Введите строку: Привет, ты сегодня занят?
# Количество символов без пробелов: 25
