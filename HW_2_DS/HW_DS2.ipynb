# %%
# !pip install pandas matplotlib seaborn requests

# %%
## Импортируем модули

from data_loader import DataLoader
from data_processing import DataProcessing
from visualization import Visualization

# %%
## Загружаем CPI датасет

url = "https://datahub.io/core/cpi-us/r/cpiai.csv"

df = DataLoader.load_csv(url)
df.head()
# Out:
#          Date  Index  Inflation
# 0  1913-01-01    9.8        NaN
# 1  1913-02-01    9.8       0.00
# 2  1913-03-01    9.8       0.00
# 3  1913-04-01    9.8       0.00
# 4  1913-05-01    9.7      -1.02

# %%
## Проверка пропусков

DataProcessing.count_missing(df)
DataProcessing.missing_report(df)
# Out:
#            Missing values  Percent (%)
# Date                    0     0.000000
# Index                   0     0.000000
# Inflation               1     0.075075

# %%
## Преобразуем дату

df= DataProcessing.to_datetime(df, "Date")
df.head()
# Out:
#         Date  Index  Inflation
# 0 1913-01-01    9.8        NaN
# 1 1913-02-01    9.8       0.00
# 2 1913-03-01    9.8       0.00
# 3 1913-04-01    9.8       0.00
# 4 1913-05-01    9.7      -1.02

# %%
## Строим графики

viz = Visualization()

viz.add_line_plot(df, x="Date", y="Index")
viz.add_histogram(df, "Index")

viz.add_line_plot(df, x="Date", y="Inflation")
viz.add_histogram(df, "Inflation")
